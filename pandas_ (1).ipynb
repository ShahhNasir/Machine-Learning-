# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series From List

# %%
# string
names = ["Amar","nehaal","Gopi","Sushmita"]
marks = [12,34,56,78]
pd.Series(names)
# Out:
# 0        Amar
# 1      nehaal
# 2        Gopi
# 3    Sushmita
# dtype: object

# %%
# integer

# %%
# custom indexing
names = ["Amar","nehaal","Gopi","Sushmita"]
marks = [12,34,56,78]

pd.Series(marks,index=["Amar","nehaal","Gopi","Sushmita"],name="Datamites Marks")
# Out:
# Amar        12
# nehaal      34
# Gopi        56
# Sushmita    78
# Name: Datamites Marks, dtype: int64

# %%
# Setting a name

# %% [markdown]
# ### From Dictionary

# %%
d = {
    "Nasir" : 24,
    "Haroon" : 23,
    "Mehraj" : 26,
    "Dhuha" : 30,
    "Nikhil" : 32
}
d
# Out:
# {'Nasir': 24, 'Haroon': 23, 'Mehraj': 26, 'Dhuha': 30, 'Nikhil': 32}

# %%
ser = pd.Series(d)

# %%
ser
# Out:
# Nasir     24
# Haroon    23
# Mehraj    26
# Dhuha     30
# Nikhil    32
# dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
e = pd.Series([1,2,3,4])
e
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
e.size
# Out:
# 4

# %%
ser
# Out:
# Nasir     24
# Haroon    23
# Mehraj    26
# Dhuha     30
# Nikhil    32
# dtype: int64

# %%
# size
ser.size
# Out:
# 5

# %%
# dtype
ser.dtype
# Out:
# dtype('int64')

# %%
# is_unique
ser.is_unique
# Out:
# True

# %%
# index
ser.index
# Out:
# Index(['Nasir', 'Haroon', 'Mehraj', 'Dhuha', 'Nikhil'], dtype='object')

# %%
# values
ser.values
# Out:
# array([24, 23, 26, 30, 32], dtype=int64)

# %% [markdown]
# ### Series Methods

# %%
d1 = {
    "Nasir" : 24,
    "Haroon" : 23,
    "Mehraj" : 26,
    "Dhuha" : 30,
    "Nikhil" : 32,
    "Gopi" : 22,
    "Surya" : 10,
    "Yashwant" : 32,
    "Nasir" : 24,
    "Haroon" : 23,
    "Mehraj" : 26,
    "Dhuha" : 30,
    "Nikhil" : 32,
    "Gopi" : 22,
    "Surya" : 10,
    "Yashwant" : 32,
}
d1
# Out:
# {'Nasir': 24,
#  'Haroon': 23,
#  'Mehraj': 26,
#  'Dhuha': 30,
#  'Nikhil': 32,
#  'Gopi': 22,
#  'Surya': 10,
#  'Yashwant': 32}

# %%
new = pd.Series({
    "Nasir" : 24,
    "Haroon" : 23,
    "Mehraj" : 26,
    "Dhuha" : 30,
    "Nikhil" : 32,
    "Gopi" : 22,
    "Surya" : 10,
    "Yashwant" : 32,
    "Nasir1" : 24,
    "Haroon2" : 23,
    "Mehraj3" : 26,
    "Dhuha4" : 30,
    "Nikhil5" : 32,
    "Gopi6" : 22,
    "Surya7" : 10,
    "Yashwant8" : 32,
})
new
# Out:
# Nasir        24
# Haroon       23
# Mehraj       26
# Dhuha        30
# Nikhil       32
# Gopi         22
# Surya        10
# Yashwant     32
# Nasir1       24
# Haroon2      23
# Mehraj3      26
# Dhuha4       30
# Nikhil5      32
# Gopi6        22
# Surya7       10
# Yashwant8    32
# dtype: int64

# %%
# head and tail
new.head(3)

new.tail()
# Out:
# Dhuha4       30
# Nikhil5      32
# Gopi6        22
# Surya7       10
# Yashwant8    32
# dtype: int64

# %%
# sample
new.sample()
# Out:
# Nasir1    24
# dtype: int64

# %%
# value_counts
new.value_counts()
# Out:
# 32    4
# 24    2
# 23    2
# 26    2
# 30    2
# 22    2
# 10    2
# Name: count, dtype: int64

# %%
# sort_values
new
# Out:
# Nasir        24
# Haroon       23
# Mehraj       26
# Dhuha        30
# Nikhil       32
# Gopi         22
# Surya        10
# Yashwant     32
# Nasir1       24
# Haroon2      23
# Mehraj3      26
# Dhuha4       30
# Nikhil5      32
# Gopi6        22
# Surya7       10
# Yashwant8    32
# dtype: int64

# %%
new.sort_values(ascending=False)
# Out:
# Nikhil       32
# Yashwant     32
# Nikhil5      32
# Yashwant8    32
# Dhuha        30
# Dhuha4       30
# Mehraj       26
# Mehraj3      26
# Nasir        24
# Nasir1       24
# Haroon       23
# Haroon2      23
# Gopi         22
# Gopi6        22
# Surya        10
# Surya7       10
# dtype: int64

# %%
# sort_index
new.sort_index()
# Out:
# Dhuha        30
# Dhuha4       30
# Gopi         22
# Gopi6        22
# Haroon       23
# Haroon2      23
# Mehraj       26
# Mehraj3      26
# Nasir        24
# Nasir1       24
# Nikhil       32
# Nikhil5      32
# Surya        10
# Surya7       10
# Yashwant     32
# Yashwant8    32
# dtype: int64

# %% [markdown]
# ### Series Maths Methods

# %%
# count
new.count()
# Out:
# 16

# %%
# sum/prod
new.sum()
new.prod()
# Out:
# 492553463754915840

# %%
# mean -> median -> mode -> std -> var
print(new.mean())
print(new.median())
print(new.mode())
print(new.std())
print(new.var())
# Out:
# 24.875
# 25.0
# 0    32
# dtype: int64
# 6.955812916786458
# 48.38333333333333

# %%
# min/max
print(new.min())
print(new.max())
# Out:
# 10
# 32

# %% [markdown]
# ### Indexing and Slicing

# %%
new
# Out:
# Nasir        24
# Haroon       23
# Mehraj       26
# Dhuha        30
# Nikhil       32
# Gopi         22
# Surya        10
# Yashwant     32
# Nasir1       24
# Haroon2      23
# Mehraj3      26
# Dhuha4       30
# Nikhil5      32
# Gopi6        22
# Surya7       10
# Yashwant8    32
# dtype: int64

# %%
new[6]
# Out:
# C:\Users\Datamites\AppData\Local\Temp\ipykernel_7232\3376233358.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new[6]
# 10

# %%
new['Surya']
# Out:
# 10

# %%
new[5:13]
# Out:
# Gopi        22
# Surya       10
# Yashwant    32
# Nasir1      24
# Haroon2     23
# Mehraj3     26
# Dhuha4      30
# Nikhil5     32
# dtype: int64

# %%
new['Gopi':'Nikhil5']
# Out:
# Gopi        22
# Surya       10
# Yashwant    32
# Nasir1      24
# Haroon2     23
# Mehraj3     26
# Dhuha4      30
# Nikhil5     32
# dtype: int64

# %%
new[new > 25]
# Out:
# Mehraj       26
# Dhuha        30
# Nikhil       32
# Yashwant     32
# Mehraj3      26
# Dhuha4       30
# Nikhil5      32
# Yashwant8    32
# dtype: int64

# %% [markdown]
# ### Editing Series

# %%
ser
# Out:
# Nasir     24
# Haroon    23
# Mehraj    26
# Dhuha     30
# Nikhil    32
# dtype: int64

# %%
# using indexing
ser[1] = 28
ser
# Out:
# C:\Users\Datamites\AppData\Local\Temp\ipykernel_7232\692184484.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   ser[1] = 28
# Nasir     24
# Haroon    28
# Mehraj    26
# Dhuha     30
# Nikhil    32
# dtype: int64

# %%
# what if an index does not exist
ser['umer'] = 90
ser
# Out:
# Nasir     24
# Haroon    28
# Mehraj    26
# Dhuha     30
# Nikhil    32
# umer      90
# dtype: int64

# %% [markdown]
# ### Series With Python Functionalities

# %%
# len/type/sorted/max/min
len(ser)
type(ser)
sorted(ser)
max(ser)
min(ser)
# Out:
# 24

# %%
# size

# %%
ser['Radhika'] = np.nan
ser
# Out:
# Nasir      24.0
# Haroon     28.0
# Mehraj     26.0
# Dhuha      30.0
# Nikhil     32.0
# umer       90.0
# Radhika     NaN
# dtype: float64

# %%
# isnull
ser.isnull().sum()
# Out:
# 1

# %%
# dropna
ser.dropna()
# Out:
# Nasir     24.0
# Haroon    28.0
# Mehraj    26.0
# Dhuha     30.0
# Nikhil    32.0
# umer      90.0
# dtype: float64

# %%
ser
# Out:
# Nasir      24.0
# Haroon     28.0
# Mehraj     26.0
# Dhuha      30.0
# Nikhil     32.0
# umer       90.0
# Radhika     NaN
# dtype: float64

# %%
# fillna
ser.fillna(4)
# Out:
# Nasir      24.0
# Haroon     28.0
# Mehraj     26.0
# Dhuha      30.0
# Nikhil     32.0
# umer       90.0
# Radhika     4.0
# dtype: float64

# %%
ser.fillna(ser.mode()[0])
# Out:
# Nasir      24.0
# Haroon     28.0
# Mehraj     26.0
# Dhuha      30.0
# Nikhil     32.0
# umer       90.0
# Radhika    24.0
# dtype: float64

# %%
ser.mode()[0]
# Out:
# 24.0

# %%
ser.dtype
# Out:
# dtype('float64')

# %%
ser.astype('float32')
# Out:
# Nasir      24.0
# Haroon     28.0
# Mehraj     26.0
# Dhuha      30.0
# Nikhil     32.0
# umer       90.0
# Radhika     NaN
# dtype: float32

# %% [markdown]
# ### DataFrame

# %% [markdown]
# #### Creating DataFrame

# %%
# using dicts
dd = {
    "Student_name" : ["Nasir","Hussain","Nikhil","Surya","Duha"],
    "CGA" : [6.5,7.6,8.0,6.7,9.9],
    "LPA" : [10,20,12,14,18]
}
dd
# Out:
# {'Student_name': ['Nasir', 'Hussain', 'Nikhil', 'Surya', 'Duha'],
#  'CGA': [6.5, 7.6, 8.0, 6.7, 9.9],
#  'LPA': [10, 20, 12, 14, 18]}

# %%
new_df = pd.DataFrame(dd)

# %%
# using read_csv
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### DataFrame Attributes and Methods

# %%
# shape
df.shape
# Out:
# (891, 12)

# %%
# dtypes
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# index
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# values
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %% [markdown]
# Methods

# %%
# head and tail
df.head(3)
df.tail(3)
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass  \
# 725          726         0       3
# 41            42         0       2
# 17            18         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 725                                Oreskovic, Mr. Luka    male  20.0      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 725      0  315094   8.6625   NaN        S
# 41       0   11668  21.0000   NaN        S
# 17       0  244373  13.0000   NaN        S

# %%
# sample

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# describe
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='O')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# isnull
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# duplicated
df.duplicated().sum()
# Out:
# 0

# %%
# rename (col={})
df.rename(columns={'Pclass':'PClass'},inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  PClass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Selecting cols from a DataFrame

# %%
# single column
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df.head(1)
# Out:
#    PassengerId  Survived  PClass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# multiple columns
df[['PassengerId','PClass','Name','Cabin']]
# Out:
#      PassengerId  PClass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#     Cabin
# 0     NaN
# 1     C85
# 2     NaN
# ...

# %% [markdown]
# ### Selecting rows from a DataFrame
#
# - **iloc** - searches using index positions
# - **loc** - searches using index labels

# %%
df.iloc[10:101]
# Out:
#      PassengerId  Survived  PClass                                  Name  \
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 11            12         1       1              Bonnell, Miss. Elizabeth
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                   ...
# 96            97         0       1             Goldschmidt, Mr. George B
# 97            98         1       1       Greenfield, Mr. William Bertram
# 98            99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 99           100         0       2                     Kantor, Mr. Sinai
# 100          101         0       3               Petranec, Miss. Matilda
#
#         Sex   Age  SibSp  Parch     Ticket     Fare    Cabin Embarked
# ...

# %%
new_df
# Out:
#   Student_name  CGA  LPA
# 0        Nasir  6.5   10
# 1      Hussain  7.6   20
# 2       Nikhil  8.0   12
# 3        Surya  6.7   14
# 4         Duha  9.9   18

# %%
df.head(1)
# Out:
#    PassengerId  Survived  PClass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# value_counts
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# sort_values
df['Age'].sort_values()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, Length: 891, dtype: float64

# %%
# sort_index
df.sort_index()
# Out:
#      PassengerId  Survived  PClass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# set_index
new_df.set_index('Student_name',inplace=True)

# %%
new_df
# Out:
#               CGA  LPA
# Student_name
# Nasir         6.5   10
# Hussain       7.6   20
# Nikhil        8.0   12
# Surya         6.7   14
# Duha          9.9   18

# %%
new_df.loc['Hussain':'Surya']
# Out:
#               CGA  LPA
# Student_name
# Hussain       7.6   20
# Nikhil        8.0   12
# Surya         6.7   14

# %%
# reset_index
new_df.reset_index(inplace=True)

# %%
new_df
# Out:
#   Student_name  CGA  LPA
# 0        Nasir  6.5   10
# 1      Hussain  7.6   20
# 2       Nikhil  8.0   12
# 3        Surya  6.7   14
# 4         Duha  9.9   18

# %%
# drop_duplicates
df.head(2)
df.drop_duplicates()
# Out:
#      PassengerId  Survived  PClass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Group by

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.groupby('Embarked')['Age'].mean()
# Out:
# Embarked
# C    30.814769
# Q    28.089286
# S    29.445397
# Name: Age, dtype: float64

# %%
groups = df.groupby('Embarked')

# %%
groups['Age'].sum()
# Out:
# Embarked
# C     4005.92
# Q      786.50
# S    16312.75
# Name: Age, dtype: float64

# %%
# first/last/nth
groups.first()
# Out:
#           PassengerId  Survived  PClass  \
# Embarked
# C                   2         1       1
# Q                   6         0       3
# S                   1         0       3
#
#                                                        Name     Sex   Age  \
# Embarked
# C         Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# Q                                          Moran, Mr. James    male   2.0
# S                                   Braund, Mr. Owen Harris    male  22.0
#
#           SibSp  Parch     Ticket     Fare Cabin
# Embarked
# C             1      0   PC 17599  71.2833   C85
# Q             0      0     330877   8.4583   C78
# S             1      0  A/5 21171   7.2500  C123

# %%
groups.last()
# Out:
#           PassengerId  Survived  PClass  \
# Embarked
# C                 890         1       1
# Q                 891         0       3
# S                 889         0       3
#
#                                               Name     Sex   Age  SibSp  \
# Embarked
# C                            Behr, Mr. Karl Howell    male  26.0      0
# Q                              Dooley, Mr. Patrick    male  32.0      0
# S         Johnston, Miss. Catherine Helen "Carrie"  female  19.0      1
#
#           Parch      Ticket   Fare Cabin
# Embarked
# C             0      111369  30.00  C148
# Q             0      370376   7.75   F38
# S             2  W./C. 6607  23.45   B42

# %%
groups.size()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64

# %%
groups.nth(7)
# Out:
#     PassengerId  Survived  PClass                             Name     Sex  \
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 36           37         1       3                 Mamee, Mr. Hanna    male
# 47           48         1       3        O'Driscoll, Miss. Bridget  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 10  4.0      1      1  PP 9549  16.7000    G6        S
# 36  NaN      0      0     2677   7.2292   NaN        C
# 47  NaN      0      0    14311   7.7500   NaN        Q

# %% [markdown]
# ### Concatenation & Merging

# %%
new_df
# Out:
#   Student_name  CGA  LPA
# 0        Nasir  6.5   10
# 1      Hussain  7.6   20
# 2       Nikhil  8.0   12
# 3        Surya  6.7   14
# 4         Duha  9.9   18

# %%
d = {
    "Student_name" : ["Hi","hello","Reddy","vishwaj","Rimidi"],
    'CGA' : [2.3,4.3,5.6,7.8,2.3],
    'LPA' : [2,3,4,5,6]
}

# %%
new_df2 = pd.DataFrame(d)
new_df2
# Out:
#   Student_name  CGA  LPA
# 0           Hi  2.3    2
# 1        hello  4.3    3
# 2        Reddy  5.6    4
# 3      vishwaj  7.8    5
# 4       Rimidi  2.3    6

# %%
# pd.concat()
pd.concat((new_df,new_df2),axis=1)
# Out:
#   Student_name  CGA  LPA Student_name  CGA  LPA
# 0        Nasir  6.5   10           Hi  2.3    2
# 1      Hussain  7.6   20        hello  4.3    3
# 2       Nikhil  8.0   12        Reddy  5.6    4
# 3        Surya  6.7   14      vishwaj  7.8    5
# 4         Duha  9.9   18       Rimidi  2.3    6

# %%
# merge

# %%
# inner/outer/left/right
